# %%
import pandas as pd

df = pd.read_csv("WA_Fn-UseC_-HR-Employee-Attrition.csv")

print(df.head())
print(df.shape)
print(df.info())
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
# Missing values
print(df.isnull().sum())
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 0

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6,4))
sns.countplot(data=df, x="Attrition")
plt.title("Employee Attrition")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x="Gender")
plt.title("Gender Distribution")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=df, x="Department")
plt.xticks(rotation=15)
plt.title("Employees by Department")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=df, x="Department", hue="Attrition")
plt.xticks(rotation=15)
plt.title("Attrition by Department")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["MonthlyIncome"], bins=30)
plt.title("Monthly Income Distribution")
plt.show()

# %%
plt.figure(figsize=(16,12))

corr = df.select_dtypes(include="number").corr()

sns.heatmap(corr, cmap="coolwarm")

plt.title("Correlation Heatmap")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["Age"], bins=20)
plt.title("Age Distribution")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x="OverTime", hue="Attrition")
plt.title("Attrition vs Overtime")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxplot(data=df, x="JobRole", y="MonthlyIncome")
plt.xticks(rotation=45)
plt.title("Monthly Income by Job Role")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x="WorkLifeBalance")
plt.title("Work-Life Balance")
plt.show()

# %%
import os

os.makedirs("images", exist_ok=True)

# %%
dept_attrition = pd.crosstab(df["Department"], df["Attrition"])

print(dept_attrition)

dept_attrition.plot(kind="bar", figsize=(8,5))

plt.title("Department-wise Attrition")
plt.ylabel("Number of Employees")
plt.xticks(rotation=15)
plt.show()
# Out:
# Attrition                No  Yes
# Department
# Human Resources          51   12
# Research & Development  828  133
# Sales                   354   92

# %%
plt.figure(figsize=(12,6))

sns.countplot(
    data=df,
    x="JobRole",
    hue="Attrition"
)

plt.xticks(rotation=45)
plt.title("Attrition by Job Role")
plt.show()

# %%
plt.figure(figsize=(6,4))

sns.countplot(
    data=df,
    x="OverTime",
    hue="Attrition"
)

plt.title("Overtime vs Attrition")
plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(
    data=df,
    x="Attrition",
    y="MonthlyIncome"
)

plt.title("Monthly Income vs Attrition")
plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(
    data=df,
    x="Attrition",
    y="Age"
)

plt.title("Age vs Attrition")
plt.show()

# %%
plt.figure(figsize=(18,12))

corr = df.select_dtypes(include="number").corr()

sns.heatmap(
    corr,
    cmap="coolwarm",
    linewidths=0.5
)

plt.title("Correlation Heatmap")

plt.show()

# %%
plt.figure(figsize=(16,12))
corr = df.select_dtypes(include="number").corr()
sns.heatmap(corr, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.savefig("images/correlation_heatmap.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x="OverTime", hue="Attrition")
plt.title("Overtime vs Attrition")
plt.savefig("images/overtime_attrition.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=df, x="Department")
plt.title("Employees by Department")
plt.xticks(rotation=15)
plt.savefig("images/department_distribution.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x="Gender")
plt.title("Gender Distribution")
plt.savefig("images/gender_distribution.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df, x="Attrition")
plt.title("Employee Attrition")
plt.savefig("images/attrition_chart.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
df.to_csv("HR_Analytics_Cleaned.csv", index=False)

print("Dataset saved successfully!")
# Out:
# Dataset saved successfully!

# %%
plt.figure(figsize=(6,4))

sns.countplot(data=df, x="Attrition")

plt.title("Employee Attrition")

plt.savefig(
    "attrition_chart.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
import os

os.makedirs("images", exist_ok=True)

# %% [markdown]
# # Conclusion
#
# This project analyzed the IBM HR Employee Attrition dataset to identify factors influencing employee turnover.
#
# ## Key Findings
# - The employee attrition rate is approximately 16%.
# - Employees working overtime have a higher likelihood of leaving.
# - Research & Development has the largest workforce.
# - Monthly income and job role show a relationship with employee attrition.
# - Work-life balance and job satisfaction are important factors in employee retention.
#
# ## Recommendations
# - Improve work-life balance initiatives.
# - Monitor overtime to reduce employee burnout.
# - Review compensation and career growth opportunities.
# - Focus retention strategies on high-risk departments and job roles.
